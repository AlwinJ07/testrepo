# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## Alwin's first Data Science Window
#
# Alwin will become a TGC Officer capable of performing data science operations

# %%
print(1+1)
# Out:
# 2

# %%
print("Alwin will become an Officer")
# Out:
# Alwin will become an Officer

# %%
2*5*5

# %%
one=2
two=1
print(one+two*(one*10))
# Out:
# 22

# %%
a=[1,2,3,4]
b=[2,4,6,8]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,b)
plt.show()
